# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.use("seaborn-v0_8-whitegrid")

# %%
data01 = pd.read_csv("alpha01/results/evaluation.csv")
data03 = pd.read_csv("alpha03/results/evaluation.csv")
data05 = pd.read_csv("alpha05/results/evaluation.csv")
data07 = pd.read_csv("alpha07/results/evaluation.csv")
data09 = pd.read_csv("alpha09/results/evaluation.csv")

# %%
baseline = data01.mean()['Stage 0']

# %%
fig, ax = plt.subplots(1)
cmap = mpl.colormaps['viridis']
ax.plot((1 - (data01.mean() / baseline)) * 100, c=cmap(0.1), label=fr"$\alpha = {0.1}$")
ax.plot((1 - (data03.mean() / baseline)) * 100, c=cmap(0.3), label=fr"$\alpha = {0.3}$")
ax.plot((1 - (data05.mean() / baseline)) * 100, c=cmap(0.5), label=fr"$\alpha = {0.5}$")
ax.plot((1 - (data07.mean() / baseline)) * 100, c=cmap(0.7), label=fr"$\alpha = {0.7}$")
ax.plot((1 - (data09.mean() / baseline)) * 100, c=cmap(0.9), label=fr"$\alpha = {0.9}$")
ax.set_ylabel("Percentage Improvement (%)", fontsize=12)
ax.legend(frameon=True)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()
# Out:
# /var/folders/wn/3cxs5bc91hsbl4gwt8j95d0h0000gp/T/ipykernel_55382/406359100.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
